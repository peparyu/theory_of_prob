# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math
from scipy.stats import expon
import seaborn as sns
import pandas as pd

# %%
plt.style.use("ggplot")
plt.rcParams.update({
    "figure.figsize": (8, 5),
    "figure.dpi": 100,
    "savefig.dpi": 300,
    "figure.constrained_layout.use": True,
    "axes.titlesize": 12,
    "axes.labelsize": 10,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "legend.fontsize": 9,
    "legend.title_fontsize": 10,
        
})

# %%
mu = 0 
sigma = 1


density = pd.DataFrame()
density["x"] = np.linspace(
    -1, 1 + 0.01, 10000
)
density["1-|x|"] = 1 - np.abs(density["x"]) 
density["0"] = np.full(10000,0)
# Calculate the area under the curve up to x = -1

# area_under_curve = expon.cdf(1, mu, sigma)

fig, ax = plt.subplots(figsize=(10, 6))
x = np.linspace(-1,1,10000)
y = x*0
# Plot the pdf of the normal distribution
ax.plot(x, 1 - np.abs(x), color="darkblue", linewidth=3)
ax.plot(np.linspace(-1.5,-1,10000),y , color="darkblue", linewidth=3)
ax.plot(np.linspace(1,1.5,10000),y , color="darkblue", label="y=1-|x|", linewidth=3)
ax.plot(np.full(10000,0),np.linspace(0,1,10000) , color="green",label='Высота', linewidth=2)
ax.plot(np.linspace(-1,1,10000),np.full(10000,0), color="red",label='Основание', linewidth=2)


# Fill the specified region with red color
ax.fill_between(x,  1 - np.abs(x), color="blue", alpha=0.1, label="Полная вероятность")

ax.set(xlabel="X", ylabel="Плотность вероятсноти")

# ax.xaxis.label.set_color("darkblue")  
# ax.yaxis.label.set_color("darkblue")  

ax.set_title("Плотность распределения", color="darkblue")

# Add the percentage value on the plot
# ax.text(0.8, 0.64, f"{area_under_curve * 100:.2f}%", color="red", fontsize=10, ha='center')

ax.legend()

plt.xticks(color='black')
plt.yticks(color='black')

# Customize the grid lines
ax.grid(True, linestyle='--', alpha=0.7)
ax.margins(-0.05, 0.05)

# Display the plot
plt.savefig('/Users/ruslanpepa/CoveringFlow/den_abs.pdf', bbox_inches='tight')
plt.show()
